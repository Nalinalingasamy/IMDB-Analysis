# %%
import pandas as pd

# %%
df = pd.read_csv("IMDB_Movies.csv")
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df.shape
# Out:
# (5043, 28)

# %%
df.isnull().sum()/len(df)*100
# Out:
# color                         0.376760
# director_name                 2.062265
# num_critic_for_reviews        0.991473
# duration                      0.297442
# director_facebook_likes       2.062265
# actor_3_facebook_likes        0.456078
# actor_2_name                  0.257783
# actor_1_facebook_likes        0.138806
# gross                        17.529248
# genres                        0.000000
# actor_1_name                  0.138806
# movie_title                   0.000000
# num_voted_users               0.000000
# cast_total_facebook_likes     0.000000
# actor_3_name                  0.456078
# facenumber_in_poster          0.257783
# plot_keywords                 3.033908
# movie_imdb_link               0.000000
# num_user_for_reviews          0.396589
# language                      0.277613
# country                       0.099147
# content_rating                6.008328
# budget                        9.756098
# title_year                    2.141582
# ...

# %%
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5043.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.159932              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews          object
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.distplot(df["duration"])
# Out:
# <Axes: xlabel='duration', ylabel='Density'>

# %%
#since duration is normally distributed--- mean replacement
print(df["duration"].mean())
df["duration"] = df["duration"].fillna(df["duration"].mean())
# Out:
# 107.2010739856802

# %%
import seaborn as sns
sns.distplot(df["num_critic_for_reviews"])
# Out:
# <Axes: xlabel='num_critic_for_reviews', ylabel='Density'>

# %%
#data is not normal=== median replacement
print(df["num_critic_for_reviews"].median())
print(df["num_critic_for_reviews"].mode()[0])
print(df["num_critic_for_reviews"].mean())
df["num_critic_for_reviews"] = df["num_critic_for_reviews"].fillna(df["num_critic_for_reviews"].median())
# Out:
# 110.0
# 1.0
# 140.1942719807731

# %%
import seaborn as sns
sns.distplot(df["director_facebook_likes"])
# Out:
# <Axes: xlabel='director_facebook_likes', ylabel='Density'>

# %%
#print(df["director_facebook_likes"].median())
#df["director_facebook_likes"]  =df["director_facebook_likes"].fillna(df["director_facebook_likes"].median())

# %%
df["director_name"] = df["director_name"].fillna("Not mentioned")
df["color"] = df["color"].fillna(df["color"].mode()[0])

# %%
#print(df["actor_3_facebook_likes"].median())
#df["actor_3_facebook_likes"]  =df["actor_3_facebook_likes"].fillna(df["actor_3_facebook_likes"].median())

# %%
df["actor_2_name"] = df["actor_2_name"].fillna("Not mentioned")
df["actor_1_name"] = df["actor_1_name"].fillna("Not mentioned")
df["actor_3_name"] = df["actor_3_name"].fillna("Not mentioned")
#df.drop("actor_2_name",axis="columns",inplace=True)
#df.drop("actor_1_name",axis="columns",inplace=True)
#df.drop("actor_3_name",axis="columns",inplace=True)

# %%
#df.drop("actor_2_facebook_likes", axis = "columns",inplace = True)
sns.distplot(df["actor_2_facebook_likes"])
#print(df["actor_2_facebook_likes"].median())
df["actor_2_facebook_likes"]  =df["actor_2_facebook_likes"].fillna("not mentioned")

# %%
#df.drop("actor_3_facebook_likes", axis = "columns",inplace = True)
sns.distplot(df["actor_3_facebook_likes"])
#print(df["actor_3_facebook_likes"].median())
df["actor_3_facebook_likes"]  =df["actor_3_facebook_likes"].fillna("not mentioned")

# %%
#df.drop("actor_1_facebook_likes",axis="columns",inplace=True)
sns.distplot(df["actor_1_facebook_likes"])
#print(df["actor_1_facebook_likes"].median())
df["actor_1_facebook_likes"]  =df["actor_1_facebook_likes"].fillna("not mentioned")

# %%
#df.drop("facenumber_in_poster",axis = "columns" ,inplace = True)
sns.distplot(df["facenumber_in_poster"])
df["facenumber_in_poster"] = df["facenumber_in_poster"].fillna(df["facenumber_in_poster"].median())

# %%
#df.drop("director_facebook_likes" , axis = "columns", inplace = True) 
sns.distplot(df["director_facebook_likes"])
df["director_facebook_likes"] = df["director_facebook_likes"].fillna(df["director_facebook_likes"].median())

# %%
sns.distplot(df["gross"])
print(df["gross"].median())
print(df["gross"].mean())
df["gross"] = df["gross"].fillna(df["gross"].median())
# Out:
# 25517500.0
# 48468407.52680933

# %%
df["plot_keywords"] = df["plot_keywords"].fillna("Not mentioned")

# %%
df['num_user_for_reviews'] = pd.to_numeric(df['num_user_for_reviews'], errors='coerce').fillna(0).astype(int)
#fills NaN to 0 and then converts to str

# %%
sns.distplot(df["num_user_for_reviews"])
print(df["num_user_for_reviews"].mean())
print(df["num_user_for_reviews"].median())
# Out:
# 271.6349395201269
# 155.0

# %%
df["num_user_for_reviews"]  =df["num_user_for_reviews"].fillna(df["num_user_for_reviews"].median())

# %%
df["language"] = df["language"].fillna(df["language"].mode()[0])
df["country"] = df["country"].fillna(df["country"].mode()[0])

# %%
df["content_rating"].unique()
# Out:
# array(['PG-13', nan, 'PG', 'G', 'R', 'TV-14', 'TV-PG', 'TV-MA', 'TV-G',
#        'Not Rated', 'Unrated', 'Approved', 'TV-Y', 'NC-17', 'X', 'TV-Y7',
#        'GP', 'Passed', 'M'], dtype=object)

# %%
df["content_rating"] = df["content_rating"].fillna("Not specified")

# %%
sns.distplot(df["budget"])
# Out:
# <Axes: xlabel='budget', ylabel='Density'>

# %%
df["budget"].median()
# Out:
# 20000000.0

# %%
df["budget"] = df["budget"].fillna(df["budget"].median())

# %%
df['title_year'].interpolate(method='linear', inplace=True)

# %%
sns.distplot(df["aspect_ratio"])
# Out:
# <Axes: xlabel='aspect_ratio', ylabel='Density'>

# %%
df["aspect_ratio"] = df["aspect_ratio"].fillna(df["aspect_ratio"].median())

# %%
df.isnull().sum()/len(df)*100
# Out:
# color                        0.0
# director_name                0.0
# num_critic_for_reviews       0.0
# duration                     0.0
# director_facebook_likes      0.0
# actor_3_facebook_likes       0.0
# actor_2_name                 0.0
# actor_1_facebook_likes       0.0
# gross                        0.0
# genres                       0.0
# actor_1_name                 0.0
# movie_title                  0.0
# num_voted_users              0.0
# cast_total_facebook_likes    0.0
# actor_3_name                 0.0
# facenumber_in_poster         0.0
# plot_keywords                0.0
# movie_imdb_link              0.0
# num_user_for_reviews         0.0
# language                     0.0
# country                      0.0
# content_rating               0.0
# budget                       0.0
# title_year                   0.0
# actor_2_facebook_likes       0.0
# imdb_score                   0.0
# aspect_ratio                 0.0
# movie_facebook_likes         0.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'genres_list'],
#       dtype='object')

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews    duration  \
# 0  Color      James Cameron                   723.0  178.000000
# 1  Color     Gore Verbinski                   302.0  169.000000
# 2  Color         Sam Mendes                   602.0  148.000000
# 3  Color  Christopher Nolan                   813.0  164.000000
# 4  Color        Doug Walker                   110.0  107.201074
#
#    director_facebook_likes actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                  855.0  Joel David Moore
# 1                    563.0                 1000.0     Orlando Bloom
# 2                      0.0                  161.0      Rory Kinnear
# 3                  22000.0                23000.0    Christian Bale
# 4                    131.0          not mentioned        Rob Walker
#
#   actor_1_facebook_likes        gross                           genres  ...  \
# 0                 1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df["genres_list"] = df["genres"].str.split("|")

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews    duration  \
# 0  Color      James Cameron                   723.0  178.000000
# 1  Color     Gore Verbinski                   302.0  169.000000
# 2  Color         Sam Mendes                   602.0  148.000000
# 3  Color  Christopher Nolan                   813.0  164.000000
# 4  Color        Doug Walker                   110.0  107.201074
#
#    director_facebook_likes actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                  855.0  Joel David Moore
# 1                    563.0                 1000.0     Orlando Bloom
# 2                      0.0                  161.0      Rory Kinnear
# 3                  22000.0                23000.0    Christian Bale
# 4                    131.0          not mentioned        Rob Walker
#
#   actor_1_facebook_likes        gross                           genres  ...  \
# 0                 1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df_exploded = df.explode('genres_list')
#df_exploded = df_exploded.drop(['genres', 'genres_list'], axis=1)
#df_merged = pd.merge(df, df_exploded, left_index=True, right_index=True, how='left')

# %%
df_exploded
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 0     Color     James Cameron                   723.0     178.0
# 0     Color     James Cameron                   723.0     178.0
# 0     Color     James Cameron                   723.0     178.0
# 0     Color     James Cameron                   723.0     178.0
# 1     Color    Gore Verbinski                   302.0     169.0
# ...     ...               ...                     ...       ...
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
# 5041  Color       Daniel Hsia                    14.0     100.0
# 5041  Color       Daniel Hsia                    14.0     100.0
# 5042  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                  855.0  Joel David Moore
# ...

# %%
df_exploded.to_excel("IMDB_SCORE_treated_DATA.xlsx")

# %%
grouped_df = df_exploded.groupby('genres_list')['imdb_score'].agg(['mean', 'median', lambda x: x.mode().iloc[0], lambda x: f"{x.min()} - {x.max()}", 'var', 'std']).reset_index()

# %%
grouped_df
# Out:
#     genres_list      mean  median  <lambda_0> <lambda_1>       var       std
# 0        Action  6.239896    6.30         6.1  1.7 - 9.1  1.251792  1.118835
# 1     Adventure  6.441170    6.60         6.7  1.9 - 8.9  1.279605  1.131196
# 2     Animation  6.576033    6.70         6.7  1.7 - 8.6  1.298676  1.139595
# 3     Biography  7.150171    7.20         7.0  4.5 - 8.9  0.522029  0.722516
# 4        Comedy  6.195246    6.30         6.7  1.7 - 9.5  1.189657  1.090714
# 5         Crime  6.564792    6.60         6.6  2.4 - 9.3  1.053613  1.026456
# 6   Documentary  7.180165    7.40         7.5  1.6 - 8.7  1.116270  1.056537
# 7         Drama  6.763763    6.90         7.2  2.0 - 9.3  0.916527  0.957354
# 8        Family  6.245055    6.40         6.7  1.7 - 8.7  1.443838  1.201598
# 9       Fantasy  6.307049    6.40         6.7  1.7 - 8.9  1.347192  1.160686
# 10    Film-Noir  7.633333    7.65         7.1  7.1 - 8.2  0.186667  0.432049
# ...

# %%
#grouped_df.columns = ['Mean', 'Median', 'Mode', 'Range', 'Variance', 'Std Dev']
grouped_df.to_excel("IMDB vs GENRE.xlsx")

# %%
df_exploded.to_excel("IMDB_SCORE_treated_DATA.xlsx")

# %%
#df_new["imdb_score"].max()
# Out:
# 9.5

# %%
#df_new["imdb_score"].min()
# Out:
# 1.6
